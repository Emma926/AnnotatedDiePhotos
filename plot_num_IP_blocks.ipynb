# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns; 

sns.set()
colors = sns.color_palette("Set1", n_colors=11)

colors = [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745), (0.21568627450980393, 0.49411764705882355, 0.7215686274509804), (0.30196078431372547, 0.6862745098039216, 0.2901960784313726), (0.596078431372549, 0.3058823529411765, 0.6392156862745098), (1.0, 0.4980392156862745, 0.0), (1.0, 1.0, 0.2), (0.6509803921568628, 0.33725490196078434, 0.1568627450980392), (0.9686274509803922, 0.5058823529411764, 0.7490196078431373), (0.6, 0.6, 0.6), (0.8941176470588236, 0.10196078431372549, 0.10980392156862745), (0.21568627450980393, 0.49411764705882355, 0.7215686274509804)]

sns.set(style="white")

# %%
blocks = [9, 12, 17, 22, 29, 31, 36, 41, 43]
labels = ['A4\n2010', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11', 'A12\n2018']

fig, ax = plt.subplots(figsize=(10,5))
ax.bar(range(len(blocks)), blocks)

ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels, fontsize = 20, rotation = 0)
ax.grid()
ax.yaxis.set_tick_params(labelsize=15)
ax.set_ylabel('# of Specialized IP Blocks', fontsize = 20)
fig.savefig('ip_blocks.pdf', bbox_inches='tight')
